# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(np.array([1, 2, 3]))
# Out:
# [1 2 3]

# %%
torch.cuda.is_available()
# Out:
# True

# %%
plt.plot([1, 3, 2]);
